# %%
hasil = 5 + 8 + 14 + 7 + 3 + 19 + 17 
print("maka RW A : " + str(hasil))

hasil2 = 4 + 4 + 14 + 7 + 9 + 18 + 15 + 9
print("maka RW B : " + str(hasil2))

hasil3 = 9 + 4 + 4 + 15 
print("maka RW C : " + str(hasil3))

hasil4 = 12 + 18 + 10 + 6 + 16 + 20 + 2 + 3 + 5 + 11 + 5 
print("maka RW D : " + str(hasil4))

hasil5 = 11 + 5 + 8 + 11 + 16 + 12 + 4 + 12 + 6 + 10 + 10
print("maka RW E : " + str(hasil5))

jml = hasil + hasil2 + hasil3 + hasil4 + hasil5
print("maka jumlah keseluruhannya adalah : " + str(jml))

print("")
total = 20 + 52 + 16 + 58 + 39 + 15 + 35
print("maka jumlah kk A : " + str(total))

total2 = 18 + 50 + 43 + 35 + 21 + 34 + 46 + 28
print("maka jumlah kk B : " + str(total2))

total3 = 30 + 48 + 24 + 42 
print("maka jumlah kk C : " + str(total3))

total4 = 42 + 28 + 25 + 45 + 29 + 24 + 26 + 59 + 20 + 30 + 18
print("maka jumlah kk D : " + str(total4))

total5 = 36 + 27 + 26 + 18 + 29+  41 + 17 + 28 + 55 + 40 + 47
print("maka jumlah kk E : " + str(total5))

jum = total + total2 + total3 + total4 + total5
print("maka total keseluruhannya : " + str(jum))

print("")
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["A", "B", "C", "D", "E"]
angka = [73,80, 35, 108, 105]
c = ['blue', 'green', 'red', 'purple', 'yellow']
plt.title("Tabel RW")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["A", "B", "C", "D", "E"]
angka = [73,80, 35, 108, 105]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel RW")
plt.show()

print("")
print("===================================================================")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["A", "B", "C", "D", "E"]
angka = [235, 275, 144, 346, 364]
c = ['blue', 'green', 'red', 'purple', 'yellow']
plt.title("Tabel KK")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["A", "B", "C", "D", "E"]
angka = [235, 275, 144, 346, 364]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel KK")
plt.show()
# Out:
# maka RW A : 73
# maka RW B : 80
# maka RW C : 32
# maka RW D : 108
# maka RW E : 105
# maka jumlah keseluruhannya adalah : 398
#
# maka jumlah kk A : 235
# maka jumlah kk B : 275
# maka jumlah kk C : 144
# maka jumlah kk D : 346
# maka jumlah kk E : 364
# maka total keseluruhannya : 1364
# ...

# %%
hasil = 51.6 + 54.6 + 57.6 + 55.8 + 56.8 + 59.4 + 51.5 + 54.9 + 50.8 + 52.6
print("maka total rentan usia >50 adalah : " + str(hasil))

hasil2 = 42.9 + 41.5 + 45.7 + 41.8 + 42.9 + 40.5 + 41.8 + 46.8 + 48.9 + 42.9 + 45.4 + 40.8
print("maka total rentan usia >40 adalah : " + str(hasil2))

hasil3 = 36.5 + 32.6 + 36.4 + 33.5 + 34.9 + 32.5 + 38.5 + 35.7 + 37.4 + 35.7 + 31.9 + 35.8 + 35.8 + 36.8 + 33.8
print("maka total rentan usia >30 adalah : " + str(hasil3))

hasil4 = 28.9 + 27.5 + 29.5 + 27.9 + 25.7 + 24.9 + 29.8 + 25.6 + 29.6 + 24.9 + 25.8 + 24.9 + 28.6
print("maka total rentan usia >20 adalah : " + str(hasil4))

total = hasil + hasil2 + hasil3 + hasil4
print("maka total keseluruhannya : " + str(total))


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = [">50", ">40", ">30", ">20"]
angka = [545.6, 521.9 , 527.8 , 353]
c = ['blue', 'green', 'red', 'purple', 'yellow']
plt.title("Tabel usia")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = [">50", ">40", ">30", ">20"]
angka = [545.6, 521.9 , 527.8 , 353]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel usia")
plt.show()
# Out:
# maka total rentan usia >50 adalah : 545.6
# maka total rentan usia >40 adalah : 521.9
# maka total rentan usia >30 adalah : 527.8
# maka total rentan usia >20 adalah : 353.6
# maka total keseluruhannya : 1948.9

# %%
hasil = 5 + 4 + 9 + 4 + 10 + 8 + 10 + 8 + 5 + 4 + 6 + 7 + 8 + 4 + 7 + 9 + 4 + 2 + 3 + 9 + 5 + 6 + 3 + 9 + 5 + 4 + 10 + 10
print("maka jumlah rw yang <10 adalah : " + str(hasil))

hasil2 = 12 + 15 + 18 + 11 + 14 + 13 + 11 + 14 + 16 + 16 + 14 + 12 + 18 + 20 + 15 + 13 + 15 + 12 + 12 + 19 + 17 + 11
print("maka jumlah rw yang >10 adalah : " + str(hasil2))

print("")
total = 600000 + 1200000 + 800000 + 1500000 + 1200000 + 1500000 + 1000000 + 800000 + 1000000 + 800000 + 1500000 + 800000 + 600000 + 600000 + 800000 + 600000 + 1200000 + 1000000 + 1200000 + 1000000 + 1200000 + 1200000 + 800000 + 1500000 + 1200000 + 1500000 + 1000000 + 600000
print("maka jumlah bantuan yang <10 : " + str(total))

total2 = 1200000 + 1000000 + 600000 + 800000 + 800000 + 600000 + 600000 + 800000 + 1500000 + 1500000 + 1000000 + 1200000 + 1500000 + 1200000 + 1000000 + 600000 + 800000 + 800000 + 600000 + 1200000 + 1000000 + 800000
print("maka jumlah bantuan yang >10 : " + str(total2))

print("")
p = 0.02 * 5 * 600000
p2 = 0.03 * 6 * 800000
p3 = 0.04 * 5 * 1000000
p4 = 0.05 * 7 * 1200000
p5 = 0.07 * 5 * 1500000

hasil = p + p2 + p3 + p4 + p5
jml = total - hasil
print("maka total pajak yang <10 : " + str(jml))

p = 0.02 * 5 * 600000
p2 = 0.03 * 6 * 800000
p3 = 0.04 * 4 * 1000000
p4 = 0.05 * 4 * 1200000
p5 = 0.07 * 3 * 1500000

hasil2 = p + p2 + p3 + p4 + p5
jml2 = total2 - hasil2
print("maka total pajak yang >10 : " + str(jml2))
# Out:
# maka jumlah rw yang <10 adalah : 178
# maka jumlah rw yang >10 adalah : 318
#
# maka jumlah bantuan yang <10 : 28700000
# maka jumlah bantuan yang >10 : 21100000
#
# maka total pajak yang <10 : 27351000.0
# maka total pajak yang >10 : 20181000.0

# %%
hasil = 800000 + 1500000 +  1000000 + 600000 + 1200000 + 600000 + 1500000 + 1200000 + 1200000 + 1200000
print("maka total bantuan rentan usia >50 : " + str(hasil))

hasil2 = 1200000 + 1200000 + 1200000 + 600000 + 800000 + 800000 + 1000000 + 1200000 + 1000000 + 1200000 + 1000000 + 800000
print("maka total bantuan rentan usia >40 : " + str(hasil2))

hasil3 = 600000 + 1500000 + 800000 + 1000000 + 1500000 + 600000 + 1500000 + 800000 + 600000 + 800000 + 800000 + 1500000 + 1500000 + 600000 + 1200000
print("maka total bantuan rentan usia >30 : " + str(hasil3))

hasil4 = 1000000 + 600000 + 800000 + 800000 + 800000 + 600000 + 1500000 + 1000000 + 1200000 + 1000000 + 800000 + 600000  + 1000000
print("maka total bantuan rentan usia >20 : " + str(hasil4))

print("")
print("===================================================================")
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = [">50", ">40", ">30", ">20"]
angka = [10800000,12000000, 15300000, 11700000]
c = ['blue', 'green', 'red', 'purple']
plt.title("Tabel Bantuan")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = [">50", ">40", ">30", ">20"]
angka = [10800000,12000000, 15300000, 11700000]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel Bantuan")
plt.show()
# Out:
# maka total bantuan rentan usia >50 : 10800000
# maka total bantuan rentan usia >40 : 12000000
# maka total bantuan rentan usia >30 : 15300000
# maka total bantuan rentan usia >20 : 11700000
#
# ...

# %%
print("soal no 5")
print("")
hasil = 600000 + 1200000 + 800000 + 1200000 + 1500000 + 1000000 + 600000 + 800000 + 1200000 + 1500000 + 800000 + 600000 + 1000000 + 800000 + 1000000 + 800000 + 1500000 + 800000 + 600000 + 600000 + 800000 + 1500000 + 600000 + 1500000 + 1000000 + 800000 + 1200000 + 600000 + 1500000 + 1200000 + 1000000 + 600000 + 1200000 + 1000000 + 1200000 + 800000 + 1000000 + 1200000 + 800000 + 1200000 + 800000 + 1500000 + 600000 + 1200000 + 1000000 + 1200000 + 800000 + 1500000 + 1000000 + 600000
print("maka jumlah semua nominal bantuan adalah : " + str(hasil))

p = 0.02 * (10 * 600000)
p2 = 0.03 * (12 * 800000)
p3 = 0.04 * (9 * 1000000)
p4 = 0.05 * (11 * 1200000)
p5 = 0.07 * (8 * 1500000)

hasil2 = p + p2 + p3 + p4 + p5
jml = hasil - hasil2
print("maka jumlah semua nominal bantuan dengan pajak adalah : " + str(jml))
# Out:
# soal no 5
#
# maka jumlah semua nominal bantuan adalah : 49800000
# maka jumlah semua nominal bantuan dengan pajak adalah : 47532000.0

# %%
import pandas as pd
from google.colab import drive #memanggil package import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/CSV/datatugas6 - Sheet1.csv'


df = pd.read_csv(path)

df.describe()
# Out:
#        Jumlah RW  Jumlah Kepala Keluarga  Rata2 Usia  Keluarga
# count  15.000000               15.000000             15.000000
# mean    9.733333               30.533333             39.233333
# std     4.216747               11.951489              9.832139
# min     4.000000               13.000000             27.500000
# 25%     6.500000               22.500000             31.050000
# 50%    10.000000               28.000000             36.500000
# 75%    12.500000               39.000000             44.300000
# max    18.000000               52.000000             57.600000

# %%
df
# Out:
#    Daerah  Jumlah RW  Jumlah Kepala Keluarga  Rata2 Usia  Keluarga  \
# 0       A          5                      20                  36.5
# 1       B          4                      18                  42.9
# 2       C          9                      30                  51.6
# 3       D         12                      42                  41.5
# 4       B          4                      50                  32.6
# 5       F         15                      16                  28.9
# 6       D         18                      28                  27.5
# 7       E         11                      36                  36.4
# 8       F         10                      28                  45.7
# 9       A          8                      52                  54.6
# 10      B         14                      43                  29.5
# 11      F         13                      13                  41.8
# 12      D         10                      25                  33.5
# ...

# %%
print("Jumlah RW A : ")
df[df['Daerah'] == 'A']['Jumlah RW'].sum()
# Out:
# Jumlah RW A :
# 13

# %%
print("Jumlah RW B : ")
df[df['Daerah'] == 'B']['Jumlah RW'].sum()
# Out:
# Jumlah RW B :
# 22

# %%
print("Jumlah RW C : ")
df[df['Daerah'] == 'C']['Jumlah RW'].sum()
# Out:
# Jumlah RW C :
# 9

# %%
print("Jumlah RW D : ")
df[df['Daerah'] == 'D']['Jumlah RW'].sum()
# Out:
# Jumlah RW D :
# 40

# %%
print("Jumlah RW E : ")
df[df['Daerah'] == 'E']['Jumlah RW'].sum()
# Out:
# Jumlah RW E :
# 16

# %%
print("Jumlah RW F : ")
df[df['Daerah'] == 'F']['Jumlah RW'].sum()
# Out:
# Jumlah RW F :
# 46

# %%
print("")
print("===================================================================")
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["RW A ", "RW B ", "RW C", "RW D", "RW E", "RW F"]
angka = [13, 22, 9, 40, 16, 46]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'brown']
plt.title("Tabel RW")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["RW A ", "RW B ", "RW C", "RW D", "RW E", "RW F"]
angka = [13, 22, 9, 40, 16, 46]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel RW")
plt.show()

# %%
print("Jumlah KK A : ")
df[df['Daerah'] == 'A']['Jumlah Kepala Keluarga'].sum()
# Out:
# Jumlah KK A :
# 72

# %%
print("Jumlah KK B : ")
df[df['Daerah'] == 'B']['Jumlah Kepala Keluarga'].sum()
# Out:
# Jumlah KK B :
# 111

# %%
print("Jumlah KK C : ")
df[df['Daerah'] == 'C']['Jumlah Kepala Keluarga'].sum()
# Out:
# Jumlah KK C :
# 30

# %%
print("Jumlah KK D : ")
df[df['Daerah'] == 'D']['Jumlah Kepala Keluarga'].sum()
# Out:
# Jumlah KK D :
# 95

# %%
print("Jumlah KK E : ")
df[df['Daerah'] == 'E']['Jumlah Kepala Keluarga'].sum()
# Out:
# Jumlah KK E :
# 63

# %%
print("Jumlah KK F : ")
df[df['Daerah'] == 'F']['Jumlah Kepala Keluarga'].sum()
# Out:
# Jumlah KK F :
# 87

# %%
print("")
print("===================================================================")
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["KK A ", "KK B ", "KK C", "KK D", "KK E", "KK F"]
angka = [72, 111, 30, 95, 63, 87]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'brown']
plt.title("Tabel KK")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["KK A ", "KK B ", "KK C", "KK D", "KK E", "KK F"]
angka = [72, 111, 30, 95, 63, 87]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel KK")
plt.show()

# %%
print("Mean Usia : ")
df['Rata2 Usia  Keluarga'].sum() / 15
# Out:
# Mean Usia :
# 39.233333333333334

# %%
hasil = 600000 + 1200000 + 800000 + 1200000 + 1500000 + 1000000 + 600000 + 800000 + 1200000 + 1500000 + 800000 + 600000 + 1000000 + 800000 + 1000000
p = 0.02 * (3 * 600000)
p2 = 0.03 * (4 * 800000)
p3 = 0.04 * (3 * 1000000)
p4 = 0.05 * (3 * 1200000)
p5 = 0.07 * (2 * 1500000)

hasil2 = p + p2 + p3 + p4 + p5
jml = hasil - hasil2
print("maka jumlah bantuannya adalah : " + str(hasil))
print("maka jumlah bantuannya + pajak adalah : " + str(jml))

print("")
print("===================================================================")
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["Nominal Bantuan ", "Nominal Bantuan + Pajak "]
angka = [14600000, 13958000]
c = ['blue', 'green']
plt.title("Tabel Bantuan")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["Nominal Bantuan ", "Nominal Bantuan + Pajak "]
angka = [14600000, 13958000]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel Bantuan")
plt.show()
# Out:
# maka jumlah bantuannya adalah : 14600000
# maka jumlah bantuannya + pajak adalah : 13958000.0
#
# ...
