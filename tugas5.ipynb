# %%
print("===================soal no 1 =====================")

karyawan = 20
asuransi = 75000
hasil = (karyawan * 300000) + (asuransi * karyawan) 
print("maka total pengeluaran dari perusahaan A-Xis : " + str(hasil))

karyawan = 14
asuransi = 75000
hasil = (karyawan * 360000) + (asuransi * karyawan) 
print("maka total pengeluaran dari perusahaan B-Log : " + str(hasil))

karyawan = 28
asuransi = 75000
hasil = (karyawan * 475000) + (asuransi * karyawan) 
print("maka total pengeluaran dari perusahaan C-in : " + str(hasil))

karyawan = 42
asuransi = 75000
hasil = (karyawan * 580000) + (asuransi * karyawan) 
print("maka total pengeluaran dari perusahaan D-namic : " + str(hasil))

karyawan = 18
asuransi = 75000
hasil = (karyawan * 400000) + (asuransi * karyawan) 
print("maka total pengeluaran dari perusahaan E-psilon : " + str(hasil))

print("")
print("============soal no 2==================")
pajak = 0.03
utang = 0.08
utang2 = 0.04
utang3 = 0.12
utang4 = 0.11
utang5 = 0.03

laba = 32500000
laba2 = 31000000
laba3 = 42000000
laba4 = 51500000
laba5 = 27000000
total = (pajak  *  laba) + (utang * 280000000)
print("maka total pajak dari perusahaan A-Xis : " + str(total))

total = (pajak  *  laba2) + (utang2 * 310000000)
print("maka total pajak dari perusahaan B-log : " + str(total))

total = (pajak  *  laba3) + (utang3 * 420000000)
print("maka total pajak dari perusahaan C-In : " + str(total))

total = (pajak  *  laba4) + (utang4 * 550000000)
print("maka total pajak dari perusahaan D-namic : " + str(total))

total = (pajak  *  laba5) + (utang5 * 340000000)
print("maka total pajak dari perusahaan E-psilon : " + str(total))

print("")
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["A-Xis", "B-Log", "C-in", "D-Namic", "E-Psilon"]
angka = [23375000, 13330000, 51660000, 62045000, 11010000]
c = ['blue', 'green', 'red', 'purple', 'yellow']
plt.title("Tabel pendapatan Perusahaan")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["A-Xis", "B-Log", "C-in", "D-Namic", "E-Psilon"]
angka = [23375000, 13330000, 51660000, 62045000, 11010000]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel pendapatan Perusahaan")
plt.show()

print("")
print("=============soal no 3================")
asset = 280000000
asset2 = 310000000
asset3 = 420000000
asset4 = 550000000
asset5 = 340000000
csr = 0.025
csr2 = 0.035

hasil = asset * csr
print('maka CSR perusahaan a adalah : ' + str(hasil))

hasil = asset2 * csr2
print('maka CSR perusahaan b adalah : ' + str(hasil))

hasil = asset3 * csr2
print('maka CSR perusahaan c adalah : ' + str(hasil))

hasil = asset4 * csr2
print('maka CSR perusahaan d adalah : ' + str(hasil))

hasil = asset5 * csr2
print('maka CSR perusahaan e adalah : ' + str(hasil))

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["A-Xis", "B-Log", "C-in", "D-Namic", "E-Psilon"]
angka = [7000000, 10850000.000000002, 14700000.000000002, 19250000, 11900000.000000002]
c = ['blue', 'green', 'red', 'purple', 'yellow']
plt.title("Tabel CSR Perusahaan")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["A-Xis", "B-Log", "C-in", "D-Namic", "E-Psilon"]
angka = [7000000, 10850000.000000002, 14700000.000000002, 19250000, 11900000.000000002]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel pendapatan Perusahaan")
plt.show()
print("==============soal no 4=================")
laba = 32500000
laba2 = 31000000
laba3 = 42000000
laba4 = 51500000
laba5 = 27000000

hasil = laba * 12
print("maka laba perusahaan a : " + str(hasil))

hasil2 = laba2 * 12
print("maka laba perusahaan b : " + str(hasil2))

hasil3 = laba3 * 12
print("maka laba perusahaan c : " + str(hasil3))

hasil4 = laba4 * 12
print("maka laba perusahaan d : " + str(hasil4))

hasil5 = laba5 * 12
print("maka laba perusahaan a : " + str(hasil5))

total = hasil + hasil2 + hasil3 + hasil4 + hasil5
print("total laba semua perusahaan selama 1 tahun adalah : " + str(total))

print("")
print("==================soal no 5================")
laba = 32500000
laba2 = 31000000
laba3 = 42000000
laba4 = 51500000
laba5 = 27000000

gaji = 300000
gaji2 = 360000
gaji3 = 475000
gaji4 = 580000
gaji5 = 400000

kar = 20
kar2 = 14
kar3 = 28
kar4 = 42
kar5 = 18
csr = 0.025
csr2 = 0.035
hasil = (laba * 12 ) - csr * 280000000 - (7500000 * 12) - 23375000
print("maka total pendapatan bersih perusahaan a : " + str(hasil))

hasil = (laba2 * 12 ) - csr2 * 310000000 - (6090000 * 12) - 13330000
print("maka total pendapatan bersih perusahaan b : " + str(hasil))

hasil = (laba3 * 12 ) - csr2 * 420000000 - (15400000 * 12) - 51660000
print("maka total pendapatan bersih perusahaan c : " + str(hasil))

hasil = (laba4 * 12 ) - csr2 * 550000000 - (27510000 * 12) - 62045000
print("maka total pendapatan bersih perusahaan d : " + str(hasil))

hasil = (laba5 * 12 ) - csr2 * 340000000 - (8550000 * 12) - 11010000
print("maka total pendapatan bersih perusahaan e : " + str(hasil))


print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["A-Xis", "B-Log", "C-in", "D-Namic", "E-Psilon"]
angka = [269625000, 274740000, 252840000, 206585000, 198490000]
c = ['blue', 'green', 'red', 'purple', 'yellow']
plt.title("Tabel Perusahaan")
plt.bar(perusahaan, angka, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["A-Xis", "B-Log", "C-in", "D-Namic", "E-Psilon"]
angka = [269625000, 274740000, 252840000, 206585000, 198490000]
ax.pie(angka, labels=perusahaan,autopct='%1.2f%%')
plt.title("Tabel Perusahaan")
plt.show()
# Out:
# ===================soal no 1 =====================
# maka total pengeluaran dari perusahaan A-Xis : 7500000
# maka total pengeluaran dari perusahaan B-Log : 6090000
# maka total pengeluaran dari perusahaan C-in : 15400000
# maka total pengeluaran dari perusahaan D-namic : 27510000
# maka total pengeluaran dari perusahaan E-psilon : 8550000
#
# ============soal no 2==================
# maka total pajak dari perusahaan A-Xis : 23375000.0
# maka total pajak dari perusahaan B-log : 13330000.0
# maka total pajak dari perusahaan C-In : 51660000.0
# maka total pajak dari perusahaan D-namic : 62045000.0
# maka total pajak dari perusahaan E-psilon : 11010000.0
# =============soal no 3================
# maka CSR perusahaan a adalah : 7000000.0
# maka CSR perusahaan b adalah : 10850000.000000002
# maka CSR perusahaan c adalah : 14700000.000000002
# maka CSR perusahaan d adalah : 19250000.0
# maka CSR perusahaan e adalah : 11900000.000000002
# ==============soal no 4=================
# ...
