# %%
#Nomor 1
print("soal no 1")
s2_a = 0
s2_b = 1
s2_c = 4
s2_d = 7
s2_e = 5
s2_f = 0
print("Tamat s2")
jumlah_s2 = s2_a + s2_b + s2_c + s2_d + s2_e + s2_f 
print("maka hasilnyaa " + str(jumlah_s2) )

print("")
s1_a = 4
s1_b = 12
s1_c = 6
s1_d = 13
s1_e = 14
s1_f = 0
print("Tamat s1")
jumlah_s1 = s1_a + s1_b + s1_c + s1_d + s1_e + s1_f 
print("maka hasilnyaa " + str(jumlah_s1) )

print("")
sma_a = 12
sma_b = 17
sma_c = 5
sma_d = 20
sma_e = 11
sma_f = 75
print("Tamat sma")
jumlah_sma = sma_a + sma_b + sma_c + sma_d + sma_e + sma_f 
print("maka hasilnyaa " + str(jumlah_sma) )

print("")
smp_a = 5
smp_b = 6
smp_c = 15
smp_d = 9
smp_e = 20
smp_f = 15
print("Tamat smp")
jumlah_smp = smp_a + smp_b + smp_c + smp_d + smp_e + smp_f 
print("maka hasilnya " + str(jumlah_smp) )

print("")
sd_a = 1
sd_b = 8
sd_c = 0
sd_d = 19
sd_e = 10
sd_f = 1
print("Tamat sd")
jumlah_sd = sd_a + sd_b + sd_c + sd_d + sd_e + sd_f 
print("maka hasilnya " + str(jumlah_sd) )

print("")
tidak_dik_a = 2
tidak_dik_b = 14
tidak_dik_c = 3
tidak_dik_d = 10
tidak_dik_e = 0
tidak_dik_f = 1
print("Tamat tidak diketahui")
jumlah_tidak = tidak_dik_a + tidak_dik_b + tidak_dik_c + tidak_dik_d + tidak_dik_e + tidak_dik_f 
print("maka hasilnya " + str(jumlah_tidak) )
print("")
print("=============soal nomor 2================")
index = 25
b_index = (jumlah_s2 / 100) * index
print("maka hasilnya " + str(b_index))

print("")
index = 20
b_index = (jumlah_s1 / 100) * index
print("maka hasilnya " + str(b_index))

print("")
index = 15
b_index = (jumlah_sma / 100) * index
print("maka hasilnya " + str(b_index))

print("")
index = 10
b_index = (jumlah_smp / 100) * index
print("maka hasilnya " + str(b_index))

print("")
index = 5
b_index = (jumlah_sd / 100) * index
print("maka hasilnya " + str(b_index))

print("")
index = 3
b_index = (jumlah_tidak / 100) * index
print("maka hasilnya " + str(b_index))


print("")
print("=========soal no 3==================")
print("")
b_index = 25
bb_index1 = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70  S2 : " + str(bb_index1))
print("")
b_index = 20
bb_index2 = (4 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70  S1 : " + str(bb_index2))
print("")
b_index = 15
bb_index3 = (12 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70  Sma : " + str(bb_index3))
print("")
b_index = 10
bb_index4 = (5 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70  Smp : " + str(bb_index4))
print("")
b_index = 5
bb_index5 = (1 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70  Sd : " + str(bb_index5))
print("")
b_index = 3
bb_index6 = (2 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70  tidak diket : " + str(bb_index6))
print("--------------------------------------------------------------------")

jml_bi= bb_index1 + bb_index2 + bb_index3 + bb_index4 + bb_index5 + bb_index6
print("maka jumlah dari keseluruhannya adalah : " + str(jml_bi))
print("")
print("====================================================================")
print("")
b_index = 25
bb_index1 = (1 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60  S2 : " + str(bb_index1))
print("")
b_index = 20
bb_index2 = (12 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60  S1 : " + str(bb_index2))
print("")
b_index = 15
bb_index3 = (17 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60  Sma : " + str(bb_index3))
print("")
b_index = 10
bb_index4 = (6 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60  Smp : " + str(bb_index4))
print("")
b_index = 5
bb_index5 = (8 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60  Sd : " + str(bb_index5))
print("")
b_index = 3
bb_index6 = (14 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60  tidak diket : " + str(bb_index6))
print("--------------------------------------------------------------------")

jml_bi= bb_index1 + bb_index2 + bb_index3 + bb_index4 + bb_index5 + bb_index6
print("maka jumlah dari keseluruhannya adalah : " + str(jml_bi))
print("")
print("====================================================================")
print("")
b_index = 25
bb_index1 = (4 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50  S2 : " + str(bb_index1))
print("")
b_index = 20
bb_index2 = (6 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50  S1 : " + str(bb_index2))
print("")
b_index = 15
bb_index3 = (5 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50  Sma : " + str(bb_index3))
print("")
b_index = 10
bb_index4 = (15 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50  Smp : " + str(bb_index4))
print("")
b_index = 5
bb_index5 = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50  Sd : " + str(bb_index5))
print("")
b_index = 3
bb_index6 = (3 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50  tidak diket : " + str(bb_index6))

print("--------------------------------------------------------------------")

jml_bi= bb_index1 + bb_index2 + bb_index3 + bb_index4 + bb_index5 + bb_index6
print("maka jumlah dari keseluruhannya adalah : " + str(jml_bi))
print("")

print("====================================================================")
print("")
b_index = 25
bb_index1 = (7 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40  S2 : " + str(bb_index1))
print("")
b_index = 20
bb_index2 = (13 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40  S1 : " + str(bb_index2))
print("")
b_index = 15
bb_index3 = (20 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40  Sma : " + str(bb_index3))
print("")
b_index = 10
bb_index4 = (9 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40  Smp : " + str(bb_index4))
print("")
b_index = 5
bb_index5 = (19 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40  Sd : " + str(bb_index5))
print("")
b_index = 3
bb_index6 = (10 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40  tidak diket : " + str(bb_index6))

print("--------------------------------------------------------------------")

jml_bi= bb_index1 + bb_index2 + bb_index3 + bb_index4 + bb_index5 + bb_index6
print("maka jumlah dari keseluruhannya adalah : " + str(jml_bi))
print("")

print("====================================================================")
print("")
b_index = 25
bb_index1 = (5 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30  S2 : " + str(bb_index1))
print("")
b_index = 20
bb_index2 = (14 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30  S1 : " + str(bb_index2))
print("")
b_index = 15
bb_index3 = (11 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30  Sma : " + str(bb_index3))
print("")
b_index = 10
bb_index4 = (10 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30  Smp : " + str(bb_index4))
print("")
b_index = 5
bb_index5 = (10 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30  Sd : " + str(bb_index5))
print("")
b_index = 3
bb_index6 = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30  tidak diket : " + str(bb_index6))

print("--------------------------------------------------------------------")

jml_bi= bb_index1 + bb_index2 + bb_index3 + bb_index4 + bb_index5 + bb_index6
print("maka jumlah dari keseluruhannya adalah : " + str(jml_bi))
print("")

print("====================================================================")
print("")
b_index = 25
bb_index1 = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20  S2 : " + str(bb_index1))
print("")
b_index = 20
bb_index2 = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20  S1 : " + str(bb_index2))
print("")
b_index = 15
bb_index3 = (75 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20  Sma : " + str(bb_index3))
print("")
b_index = 10
bb_index4 = (15 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20  Smp : " + str(bb_index4))
print("")
b_index = 5
bb_index5 = (1 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20  Sd : " + str(bb_index5))
print("")
b_index = 3
bb_index6 = (1 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20  tidak diket : " + str(bb_index6))

print("--------------------------------------------------------------------")

jml_bi= bb_index1 + bb_index2 + bb_index3 + bb_index4 + bb_index5 + bb_index6
print("maka jumlah dari keseluruhannya adalah : " + str(jml_bi))
print("")

print("")
print("====================Soal no 4==================================")
min = [3.2099999]
print("maka usia dengan indeks mutu pendidikan paling kecil adalah usia >70 : " + str(min))
# Out:
# soal no 1
# Tamat s2
# maka hasilnyaa 17
#
# Tamat s1
# maka hasilnyaa 49
#
# Tamat sma
# maka hasilnyaa 140
#
# Tamat smp
# maka hasilnya 70
#
# Tamat sd
# maka hasilnya 39
#
# Tamat tidak diketahui
# maka hasilnya 30
#
# =============soal nomor 2================
# maka hasilnya 4.25
#
# maka hasilnya 9.8
#
# maka hasilnya 21.0
#
# maka hasilnya 7.0
#
# maka hasilnya 1.9500000000000002
#
# maka hasilnya 0.8999999999999999
#
# =========soal no 3==================
#
# maka bobot index mutu dari rentan usia >70  S2 : 0.0
#
# maka bobot index mutu dari rentan usia >70  S1 : 0.8
#
# maka bobot index mutu dari rentan usia >70  Sma : 1.7999999999999998
#
# maka bobot index mutu dari rentan usia >70  Smp : 0.5
#
# maka bobot index mutu dari rentan usia >70  Sd : 0.05
#
# maka bobot index mutu dari rentan usia >70  tidak diket : 0.06
# --------------------------------------------------------------------
# maka jumlah dari keseluruhannya adalah : 3.2099999999999995
#
# ...
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
lulusan = ["S2", "S1", "SMA", "SMP", "SD", "Tidak Diketahui"]
angka = [17, 49, 140, 70, 39, 30]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'black']
plt.title("Jumlah keseluruhan")
plt.bar(lulusan, angka, color = c)
plt.show()
print("")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
lulusan = ["S2", "S1", "SMA", "SMP", "SD", "Tidak Diketahui"]
angka = [17, 49, 140, 70, 39, 30]
ax.pie(angka, labels=lulusan,autopct='%1.2f%%')
plt.title("Jumlah keseluruhan")
plt.show()

print("")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
usia = [">70", ">60", ">50", ">40", ">30", ">20"]
angka = [24, 58, 33, 78, 60, 92]
ax.pie(angka, labels=usia,autopct='%1.2f%%')
plt.title("Jumlah keseluruhan berdasarkan usia")
plt.show()

print("")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usia = [">70", ">60", ">50", ">40", ">30", ">20"]
angka = [24, 58, 33, 78, 60, 92]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'black']
plt.title("Jumlah keseluruhan berdasarkan usia")
plt.bar(usia, angka, color = c)
plt.show()
